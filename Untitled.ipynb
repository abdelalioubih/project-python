# %% [markdown]
# OUBIH ABDELALI ,  FILLIER:IOT_R , APOGEE : 21006028

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")  #df petit pour simplifier ;e tapie de code pour moi
# Informations générales sur les données
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.head(10) # affiche de 10 ligne
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.columns #affiche tout colonne
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#Visualisations
# Histogramme

# %%
plt.hist(df['bedrooms'])
plt.axvline(df['bedrooms'].mean(), color="red",linewidth=2, linestyle='--')

plt.title("price")
# Out:
# Text(0.5, 1.0, 'price')

# %%
#Analyse statistique
print("\nMoyenne:", df_clean['bedrooms'].mean())
print("Médiane:", df_clean['bedrooms'].median())
print("Écart-type:", df_clean['bedrooms'].std())
# Out:
# Moyenne: 3.37084162309721
# Médiane: 3.0
# Écart-type: 0.9300618311474632

# %%
df.describe().T.style.bar(subset=['std'],color='yellow')
# Out:
# <style type="text/css">
# #T_edc11_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, yellow 100.0%, transparent 100.0%);
# }
# #T_edc11_row1_col2, #T_edc11_row2_col2, #T_edc11_row3_col2, #T_edc11_row4_col2, #T_edc11_row5_col2, #T_edc11_row6_col2, #T_edc11_row7_col2, #T_edc11_row8_col2, #T_edc11_row9_col2, #T_edc11_row10_col2, #T_edc11_row11_col2, #T_edc11_row12_col2, #T_edc11_row13_col2, #T_edc11_row14_col2, #T_edc11_row15_col2, #T_edc11_row16_col2, #T_edc11_row17_col2, #T_edc11_row18_col2, #T_edc11_row19_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, yellow 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_edc11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edc11_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_edc11_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_edc11_level0_col2" class="col_heading level0 col2" >std</th>
# ...

# %%
print("\nValeurs manquantes:")
print(df.isnull().sum())
# Out:
# Valeurs manquantes:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# Suppression des lignes avec valeurs manquantes
df_clean = df.dropna()

# %%
# Création d'une nouvelle colonne
df_clean['NC'] = df_clean['floors'] + df_clean['grade'] 
# Tri des données
sorted_df = df_clean.sort_values(by='view', ascending=False)

# %%
# Exemple de sélection de colonnes
colonnes_selection = ['id', 'date']  
print(df_clean[colonnes_selection].head())
# Out:
#            id             date
# 0  7129300520  20141013T000000
# 1  6414100192  20141209T000000
# 2  5631500400  20150225T000000
# 3  2487200875  20141209T000000
# 4  1954400510  20150218T000000

# %%
# Filtrage de données (exemple: price )
filtre = df_clean[df_clean['price'] > 257500.00]
print(filtre)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 7      2008000270  20150115T000000   291850.0         3       1.50
# ...           ...              ...        ...       ...        ...
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# ...

# %%
# Courbe (ex: en fonction du temps)
df_clean.plot(x='date', y='price')
plt.title("prix")
plt.xlabel("date")
plt.ylabel("prix")
plt.show()
